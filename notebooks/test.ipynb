# %%
# %env ALL_PROXY=http://127.0.0.1:7890
# %env HTTP_PROXY=http://127.0.0.1:7890
# %env HTTPS_PROXY=http://127.0.0.1:7890
# Out:
# env: ALL_PROXY=http://127.0.0.1:7890
# env: HTTP_PROXY=http://127.0.0.1:7890
# env: HTTPS_PROXY=http://127.0.0.1:7890

# %%
# !curl google.com

# %%
from datasets import load_dataset

dataset = load_dataset(
    "IWSLT/iwslt2017", "iwslt2017-en-de", trust_remote_code=True
)

# 数据集包含 'train', 'validation', 'test'
print(dataset)
print("训练集示例:", dataset["train"][0])
# Out:
# Generating train split: 100%|██████████| 206112/206112 [00:05<00:00, 40431.80 examples/s]
# Generating test split: 100%|██████████| 8079/8079 [00:00<00:00, 35461.51 examples/s]
# Generating validation split: 100%|██████████| 888/888 [00:00<00:00, 27436.77 examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['translation'],
#         num_rows: 206112
#     })
#     test: Dataset({
#         features: ['translation'],
#         num_rows: 8079
#     })
#     validation: Dataset({
#         features: ['translation'],
#         num_rows: 888
#     })
# })
# 训练集示例: {'translation': {'de': 'Vielen Dank, Chris.', 'en': 'Thank you so much, Chris.'}}

# %%
type(dataset['train'])
# Out:
# datasets.arrow_dataset.Dataset
